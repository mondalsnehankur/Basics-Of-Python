# %%
# Q1. Student Fee Management System

total_fee = 120000
paid_amount = 45000
remaining_fee = total_fee - paid_amount

print("Total Fee       : Rs.", total_fee)
print("Paid Amount     : Rs.", paid_amount)
print("Remaining Fee   : Rs.", remaining_fee)
# Out:
# Total Fee       : Rs. 120000
# Paid Amount     : Rs. 45000
# Remaining Fee   : Rs. 75000

# %%
# Q2. Restaurant Bill Sharing

total_bill = 1200
friends = 4
share = total_bill / friends

print("Total Bill      : Rs.", total_bill)
print("Each Friend Pays: Rs.", share)
# Out:
# Total Bill      : Rs. 1200
# Each Friend Pays: Rs. 300.0

# %%
# Q3. Fuel Cost Estimation

mileage = 45
distance = 180
price_per_litre = 105
litres_needed = distance / mileage
fuel_cost = litres_needed * price_per_litre

print("Distance        :", distance, "km")
print("Petrol Price    : Rs.", price_per_litre, "per litre")
print("Litres Needed   :", litres_needed)
print("Estimated Cost  : Rs.", fuel_cost)
# Out:
# Distance        : 180 km
# Petrol Price    : Rs. 105 per litre
# Litres Needed   : 4.0
# Estimated Cost  : Rs. 420.0

# %%
# Q4. Employee Salary Revision

current_salary = 50000
increment_percent = 12
increment = (increment_percent / 100) * current_salary
revised_salary = current_salary + increment

print("Current Salary  : Rs.", current_salary)
print("Increment (12%) : Rs.", increment)
print("Revised Salary  : Rs.", revised_salary)
# Out:
# Current Salary  : Rs. 50000
# Increment (12%) : Rs. 6000.0
# Revised Salary  : Rs. 56000.0

# %%
# Q5. Retail Discount Calculator

purchase_amount = 4250
discount_percent = 15
discount = (discount_percent / 100) * purchase_amount
final_amount = purchase_amount - discount

print("Purchase Amount : Rs.", purchase_amount)
print("Discount (15%)  : Rs.", discount)
print("Final Amount    : Rs.", final_amount)
# Out:
# Purchase Amount : Rs. 4250
# Discount (15%)  : Rs. 637.5
# Final Amount    : Rs. 3612.5

# %%
# Q6. Mobile Data Converter

data_gb = 2.5
data_mb = data_gb * 1024

print("Daily Data Pack :", data_gb, "GB")
print("In Megabytes    :", data_mb, "MB")
# Out:
# Daily Data Pack : 2.5 GB
# In Megabytes    : 2560.0 MB

# %%
# Q7. Temperature Conversion Utility

celsius = 37
fahrenheit = (celsius * 9/5) + 32

print("Temperature (C) :", celsius)
print("Temperature (F) :", fahrenheit)
# Out:
# Temperature (C) : 37
# Temperature (F) : 98.6

# %%
# Q8. Video Lecture Duration

total_minutes = 145
hours = total_minutes // 60
minutes = total_minutes % 60

print("Total Duration  :", total_minutes, "minutes")
print("Converted       :", hours, "hours", minutes, "minutes")
# Out:
# Total Duration  : 145 minutes
# Converted       : 2 hours 25 minutes

# %%
# Q9. University Email Generator

first_name = "Rahul"
last_name = "Sharma"
email = (first_name + "." + last_name + "@college.edu").lower()

print("Generated Email :", email)
# Out:
# Generated Email : rahul.sharma@college.edu

# %%
# Q10. Product Code Generator

product_name = "Laptop"
product_id = "PRD98765"
product_code = product_name[:3].upper() + product_id[-3:]

print("Product Name    :", product_name)
print("Product ID      :", product_id)
print("Product Code    :", product_code)
# Out:
# Product Name    : Laptop
# Product ID      : PRD98765
# Product Code    : LAP765

# %%
# Q11. Password Validation System

password = "Secure@1"

if len(password) >= 8:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Strong Password

# %%
# Q12. Username Formatter

username = "JohnDoe"

print("Original  :", username)
print("Uppercase :", username.upper())
print("Lowercase :", username.lower())
# Out:
# Original  : JohnDoe
# Uppercase : JOHNDOE
# Lowercase : johndoe

# %%
# Q13. Movie Information System

movie_name = "Interstellar"

print("Movie Title     :", movie_name)
print("Character Count :", len(movie_name))
# Out:
# Movie Title     : Interstellar
# Character Count : 12

# %%
# Q14. Social Media Status Analyzer

status = "Hello World!"

print("Status Message  :", status)
print("First Character :", status[0])
print("Last Character  :", status[-1])
# Out:
# Status Message  : Hello World!
# First Character : H
# Last Character  : !

# %%
# Q15. City Name Formatter

city = "   Mumbai   "
cleaned_city = city.strip()

print("Original (with spaces):", repr(city))
print("Cleaned City          :", cleaned_city)
# Out:
# Original (with spaces): '   Mumbai   '
# Cleaned City          : Mumbai

# %%
# Q16. Shopping Cart Management

grocery = ["Apples", "Bread", "Milk", "Eggs", "Rice"]

print("First Item      :", grocery[0])
print("Last Item       :", grocery[-1])
print("Total Items     :", len(grocery))
# Out:
# First Item      : Apples
# Last Item       : Rice
# Total Items     : 5

# %%
# Q17. Student Performance Analysis

marks = [78, 92, 85, 67, 90]

print("Marks           :", marks)
print("Highest Marks   :", max(marks))
print("Lowest Marks    :", min(marks))
# Out:
# Marks           : [78, 92, 85, 67, 90]
# Highest Marks   : 92
# Lowest Marks    : 67

# %%
# Q18. Cricket Team Update

players = ["Rohit", "Virat", "KL Rahul", "Gill", "Surya",
           "Hardik", "Jadeja", "Ashwin", "Bumrah", "Shami", "Siraj"]

print("Original Team   :", players)
players[3] = "Iyer"
print("Updated Team    :", players)
# Out:
# Original Team   : ['Rohit', 'Virat', 'KL Rahul', 'Gill', 'Surya', 'Hardik', 'Jadeja', 'Ashwin', 'Bumrah', 'Shami', 'Siraj']
# Updated Team    : ['Rohit', 'Virat', 'KL Rahul', 'Iyer', 'Surya', 'Hardik', 'Jadeja', 'Ashwin', 'Bumrah', 'Shami', 'Siraj']

# %%
# Q19. Online Shopping Order

orders = ["Phone", "Laptop", "Headphones", "Keyboard"]

print("Original Order  :", orders)
orders.remove("Headphones")
print("Updated Order   :", orders)
# Out:
# Original Order  : ['Phone', 'Laptop', 'Headphones', 'Keyboard']
# Updated Order   : ['Phone', 'Laptop', 'Keyboard']

# %%
# Q20. Movie Collection Organizer

movies = ["Inception", "Avatar", "Dune", "Batman", "Coco"]
movies.sort()

print("Sorted Movies   :", movies)
# Out:
# Sorted Movies   : ['Avatar', 'Batman', 'Coco', 'Dune', 'Inception']

# %%
# Q21. Laptop Price Comparison

prices = [55000, 72000, 48000, 89000]

print("Prices          :", prices)
print("Highest Price   : Rs.", max(prices))
print("Lowest Price    : Rs.", min(prices))
# Out:
# Prices          : [55000, 72000, 48000, 89000]
# Highest Price   : Rs. 89000
# Lowest Price    : Rs. 48000

# %%
# Q22. Classroom Seating Record

students = ["Aisha", "Bala", "Charan", "Divya", "Elan", "Farhan"]

print("First Student   :", students[0])
print("Last Student    :", students[-1])
# Out:
# First Student   : Aisha
# Last Student    : Farhan

# %%
# Q23. GPS Location Record

location = (28.6139, 77.2090)

print("Latitude        :", location[0])
print("Longitude       :", location[1])
# Out:
# Latitude        : 28.6139
# Longitude       : 77.209

# %%
# Q24. RGB Color Representation

rgb = (255, 128, 64)

print("Red   :", rgb[0])
print("Green :", rgb[1])
print("Blue  :", rgb[2])
# Out:
# Red   : 255
# Green : 128
# Blue  : 64

# %%
# Q25. Semester Subject List

subjects = ("Mathematics", "Physics", "Chemistry", "English", "Computer Science")

print("Subjects        :", subjects)
print("Third Subject   :", subjects[2])
# Out:
# Subjects        : ('Mathematics', 'Physics', 'Chemistry', 'English', 'Computer Science')
# Third Subject   : Chemistry

# %%
# Q26. Employee Information System

employee = (1021, "Amit Kumar", "Finance", 65000)

print("Employee ID     :", employee[0])
print("Name            :", employee[1])
print("Department      :", employee[2])
print("Salary          : Rs.", employee[3])
# Out:
# Employee ID     : 1021
# Name            : Amit Kumar
# Department      : Finance
# Salary          : Rs. 65000

# %%
# Q27. Flight Information Record

flight = ("AI-202", "Dubai", "14:30")

print("Flight Number   :", flight[0])
print("Destination     :", flight[1])
print("Departure Time  :", flight[2])
# Out:
# Flight Number   : AI-202
# Destination     : Dubai
# Departure Time  : 14:30

# %%
# Q28. Workshop Registration System

registrations = {101, 102, 103, 101, 104, 102}

print("Unique Student IDs:", sorted(registrations))
# Out:
# Unique Student IDs: [101, 102, 103, 104]

# %%
# Q29. Library Membership System

members = {201, 202, 203, 204}
members.add(205)

print("Updated Members :", sorted(members))
# Out:
# Updated Members : [201, 202, 203, 204, 205]

# %%
# Q30. Online Gaming Portal

players = {"alex", "rina", "mario", "lisa"}
players.discard("mario")

print("Active Players  :", sorted(players))
# Out:
# Active Players  : ['alex', 'lisa', 'rina']

# %%
# Q31. Student Workshop Participation

ai_workshop = {"Alice", "Bob", "Charlie", "Diana"}
py_workshop = {"Bob", "Diana", "Eve", "Frank"}
both = ai_workshop & py_workshop

print("Registered for both workshops:", sorted(both))
# Out:
# Registered for both workshops: ['Bob', 'Diana']

# %%
# Q32. College Club Membership

coding_club = {"Arjun", "Meena", "Karan", "Priya"}
robotics_club = {"Meena", "Raj", "Karan", "Sana"}
all_members = coding_club | robotics_club

print("All Unique Members:", sorted(all_members))
# Out:
# All Unique Members: ['Arjun', 'Karan', 'Meena', 'Priya', 'Raj', 'Sana']

# %%
# Q33. Student Profile Management

student = {"Name": "Pooja Nair", "Age": 20, "Course": "B.Tech", "University": "VIT"}

for key, value in student.items():
    print(f"{key:<12}: {value}")
# Out:
# Name        : Pooja Nair
# Age         : 20
# Course      : B.Tech
# University  : VIT

# %%
# Q34. Product Inventory System

product = {"Name": "Notebook", "Price": 150, "Quantity": 200}
total_value = product["Price"] * product["Quantity"]

print("Product         :", product["Name"])
print("Price           : Rs.", product["Price"])
print("Quantity        :", product["Quantity"])
print("Inventory Value : Rs.", total_value)
# Out:
# Product         : Notebook
# Price           : Rs. 150
# Quantity        : 200
# Inventory Value : Rs. 30000

# %%
# Q35. Employee Record Management

employee = {"Name": "Ramesh", "Department": "IT", "Salary": 50000}
employee["Salary"] = 62000

print("Updated Record:")
for k, v in employee.items():
    print(f"  {k}: {v}")
# Out:
# Updated Record:
#   Name: Ramesh
#   Department: IT
#   Salary: 62000

# %%
# Q36. Cricket Scoreboard System

scores = {"Rohit": 85, "Virat": 102, "KL Rahul": 47}
player = "Virat"

print(f"{player}'s Score: {scores[player]}")
# Out:
# Virat's Score: 102

# %%
# Q37. Hospital Patient Record

patient = {"Name": "Suresh", "Age": 45, "Blood Group": "B+", "City": "Chennai"}

print("Patient Blood Group:", patient["Blood Group"])
# Out:
# Patient Blood Group: B+

# %%
# Q38. University Scholarship Evaluation

percentage = 85

if percentage >= 90:
    status = "Full Scholarship"
elif percentage >= 80:
    status = "50% Scholarship"
elif percentage >= 70:
    status = "25% Scholarship"
else:
    status = "No Scholarship"

print(f"Percentage      : {percentage}%")
print("Scholarship     :", status)
# Out:
# Percentage      : 85%
# Scholarship     : 50% Scholarship

# %%
# Q39. E-Commerce Delivery Charge Calculator

order_value = 1500

if order_value > 2000:
    msg = "Free Delivery"
elif order_value >= 1000:
    msg = "Delivery Charge: Rs. 50"
else:
    msg = "Delivery Charge: Rs. 100"

print(f"Order Value     : Rs. {order_value}")
print("Delivery        :", msg)
# Out:
# Order Value     : Rs. 1500
# Delivery        : Delivery Charge: Rs. 50

# %%
# Q40. Electricity Billing System

units = 350

if units <= 100:
    bill = units * 5
elif units <= 300:
    bill = (100 * 5) + (units - 100) * 7
else:
    bill = (100 * 5) + (200 * 7) + (units - 300) * 10

print(f"Units Consumed  : {units}")
print(f"Electricity Bill: Rs. {bill}")
# Out:
# Units Consumed  : 350
# Electricity Bill: Rs. 2400

# %%
# Q41. University Admission Eligibility System

scores = [88, 76, 90]
avg = sum(scores) / len(scores)

if avg >= 85:
    status = "Direct Admission"
elif avg >= 70:
    status = "Interview Round"
else:
    status = "Not Eligible"

print(f"Scores          : {scores}")
print(f"Average         : {avg:.2f}")
print("Admission Status:", status)
# Out:
# Scores          : [88, 76, 90]
# Average         : 84.67
# Admission Status: Interview Round

# %%
# Q42. Smart Parking Fee Calculator

hours = 7

if hours <= 2:
    fee = hours * 30
elif hours <= 5:
    fee = (2 * 30) + (hours - 2) * 20
else:
    fee = (2 * 30) + (3 * 20) + (hours - 5) * 15

print(f"Parking Hours   : {hours}")
print(f"Total Fee       : Rs. {fee}")
# Out:
# Parking Hours   : 7
# Total Fee       : Rs. 150

# %%
# Q43. Employee Performance Evaluation System

attendance = 90
project_score = 78
client_feedback = 8

weighted = (attendance * 0.20) + (project_score * 0.50) + (client_feedback * 10 * 0.30)

if weighted >= 85:
    category = "Excellent"
elif weighted >= 70:
    category = "Good"
elif weighted >= 50:
    category = "Average"
else:
    category = "Poor"

print(f"Weighted Score  : {weighted:.2f}")
print("Performance     :", category)
# Out:
# Weighted Score  : 81.00
# Performance     : Good

# %%
# Q44. E-Commerce Billing System

p1, q1 = 800, 2
p2, q2 = 1500, 1
p3, q3 = 600, 3

subtotal = p1 * q1 + p2 * q2 + p3 * q3
discount = subtotal * 0.10 if subtotal > 5000 else 0
after_discount = subtotal - discount
gst = after_discount * 0.18
total = after_discount + gst

print(f"Subtotal        : Rs. {subtotal}")
print(f"Discount (10%)  : Rs. {discount}")
print(f"GST (18%)       : Rs. {gst:.2f}")
print(f"Final Amount    : Rs. {total:.2f}")
# Out:
# Subtotal        : Rs. 4900
# Discount (10%)  : Rs. 0
# GST (18%)       : Rs. 882.00
# Final Amount    : Rs. 5782.00

# %%
# Q45. Electricity Billing Management System

units = 450

if units <= 100:
    bill = units * 5
elif units <= 300:
    bill = (100 * 5) + (units - 100) * 7
else:
    bill = (100 * 5) + (200 * 7) + (units - 300) * 10

total = bill + 150

print(f"Units           : {units}")
print(f"Bill Amount     : Rs. {bill}")
print(f"Maintenance     : Rs. 150")
print(f"Total Bill      : Rs. {total}")
# Out:
# Units           : 450
# Bill Amount     : Rs. 3400
# Maintenance     : Rs. 150
# Total Bill      : Rs. 3550

# %%
# Q46. Online Food Ordering System

food_bill = 1600
delivery = 0 if food_bill > 800 else 50
discount = food_bill * 0.05 if food_bill > 1500 else 0
after_discount = food_bill - discount
gst = after_discount * 0.05
total = after_discount + gst + delivery

print(f"Food Bill       : Rs. {food_bill}")
print(f"Discount (5%)   : Rs. {discount}")
print(f"GST (5%)        : Rs. {gst:.2f}")
print(f"Delivery Charge : Rs. {delivery}")
print(f"Final Amount    : Rs. {total:.2f}")
# Out:
# Food Bill       : Rs. 1600
# Discount (5%)   : Rs. 80.0
# GST (5%)        : Rs. 76.00
# Delivery Charge : Rs. 0
# Final Amount    : Rs. 1596.00

# %%
# Q47. Flight Ticket Reservation System

travel_class = "Economy"
age = 65

base_fare = 4500 if travel_class == "Economy" else 8500
fare = base_fare * 0.85 if age >= 60 else base_fare

print(f"Class           : {travel_class}")
print(f"Age             : {age}")
print(f"Fare Payable    : Rs. {fare:.2f}")
# Out:
# Class           : Economy
# Age             : 65
# Fare Payable    : Rs. 3825.00

# %%
# Q48. Mobile Recharge Recommendation System

amount = 599

if 199 <= amount <= 399:
    plan = "1 GB/day"
elif 400 <= amount <= 699:
    plan = "2 GB/day"
elif amount >= 700:
    plan = "3 GB/day + OTT Subscription"
else:
    plan = "No Plan Available"

print(f"Recharge Amount : Rs. {amount}")
print("Recommended Plan:", plan)
# Out:
# Recharge Amount : Rs. 599
# Recommended Plan: 2 GB/day

# %%
# Q49. Password Validation System (Advanced)

password = "Secure@9"
has_length = len(password) >= 8
has_at = "@" in password
has_digit = any(c.isdigit() for c in password)

if has_length and has_at and has_digit:
    print("Password Status : Valid")
else:
    print("Password Status : Invalid")
    if not has_length:
        print("  - Minimum 8 characters required")
    if not has_at:
        print("  - '@' symbol required")
    if not has_digit:
        print("  - At least one digit required")
# Out:
# Password Status : Valid

# %%
# Q50. Banking Interest Calculator

principal = 600000
rate = 7.0
time = 3

if principal > 500000:
    rate += 0.5

interest = (principal * rate * time) / 100
total = principal + interest

print(f"Principal       : Rs. {principal}")
print(f"Rate of Interest: {rate}%")
print(f"Simple Interest : Rs. {interest}")
print(f"Total Amount    : Rs. {total}")
# Out:
# Principal       : Rs. 600000
# Rate of Interest: 7.5%
# Simple Interest : Rs. 135000.0
# Total Amount    : Rs. 735000.0

# %%
# Q51. Hospital Patient Billing System

patient = {"Name": "Ramya", "Room": 101, "Consultation": 500, "Room Charges": 2000}
patient["Room"] = 205
total_bill = patient["Consultation"] + patient["Room Charges"]

print("Patient Name    :", patient["Name"])
print("Room Number     :", patient["Room"])
print("Consultation    : Rs.", patient["Consultation"])
print("Room Charges    : Rs.", patient["Room Charges"])
print("Total Bill      : Rs.", total_bill)
# Out:
# Patient Name    : Ramya
# Room Number     : 205
# Consultation    : Rs. 500
# Room Charges    : Rs. 2000
# Total Bill      : Rs. 2500

# %%
# Q52. Student Academic Performance Report

marks = [88, 76, 91, 65, 80]
total = sum(marks)
percentage = total / 500 * 100
highest = max(marks)
lowest = min(marks)

if percentage >= 90:
    grade = "O"
elif percentage >= 80:
    grade = "A+"
elif percentage >= 70:
    grade = "A"
elif percentage >= 60:
    grade = "B"
else:
    grade = "C"

print(f"Marks           : {marks}")
print(f"Total           : {total}/500")
print(f"Percentage      : {percentage:.2f}%")
print(f"Highest Mark    : {highest}")
print(f"Lowest Mark     : {lowest}")
print(f"Grade           : {grade}")
# Out:
# Marks           : [88, 76, 91, 65, 80]
# Total           : 400/500
# Percentage      : 80.00%
# Highest Mark    : 91
# Lowest Mark     : 65
# Grade           : A+

# %%
# Q53. Grocery Store Billing System

prices = [120, 250, 85, 310, 175]
total = sum(prices)
gst = total * 0.08
final = total + gst

print(f"Item Prices     : {prices}")
print(f"Highest Price   : Rs. {max(prices)}")
print(f"Lowest Price    : Rs. {min(prices)}")
print(f"Subtotal        : Rs. {total}")
print(f"GST (8%)        : Rs. {gst:.2f}")
print(f"Final Bill      : Rs. {final:.2f}")
# Out:
# Item Prices     : [120, 250, 85, 310, 175]
# Highest Price   : Rs. 310
# Lowest Price    : Rs. 85
# Subtotal        : Rs. 940
# GST (8%)        : Rs. 75.20
# Final Bill      : Rs. 1015.20

# %%
# Q54. Library Book Management System

books = ["Python Basics", "Data Structures", "DBMS", "OS Concepts", "Networks"]
books.remove("DBMS")
books.append("Machine Learning")

print("Updated Book List:", books)
# Out:
# Updated Book List: ['Python Basics', 'Data Structures', 'OS Concepts', 'Networks', 'Machine Learning']

# %%
# Q55. Employee Record Management System

emp = {"Name": "Kavitha", "Department": "HR", "Designation": "Executive", "Salary": 40000}
emp["Department"] = "Management"
emp["Salary"] = 55000

print("Updated Employee Record:")
for k, v in emp.items():
    print(f"  {k}: {v}")
# Out:
# Updated Employee Record:
#   Name: Kavitha
#   Department: Management
#   Designation: Executive
#   Salary: 55000

# %%
# Q56. University ID Generation System

first = "Aarav"
last = "Mehta"
reg_no = "REG2024"
year = "2024"

uid = f"{year}-{first[:3].upper()}-{last[:3].upper()}-{reg_no}"
print("University ID   :", uid)
# Out:
# University ID   : 2024-AAR-MEH-REG2024

# %%
# Q57. Digital Wallet Management System

wallet1 = 4500
wallet2 = 3200
wallet3 = 6000
total = wallet1 + wallet2 + wallet3

print(f"Total Balance   : Rs. {total}")
if total > 10000:
    print("Status          : Premium Wallet User")
# Out:
# Total Balance   : Rs. 13700
# Status          : Premium Wallet User

# %%
# Q58. Online Shopping Cart Management

cart = ["Phone", "Tablet", "Watch", "Earbuds", "Charger"]
cancelled = "Watch"
pos = cart.index(cancelled)
cart.remove(cancelled)
cart.insert(pos, "SmartBand")

print("Updated Cart    :", cart)
# Out:
# Updated Cart    : ['Phone', 'Tablet', 'SmartBand', 'Earbuds', 'Charger']

# %%
# Q59. Cricket Performance Analysis System

p1 = {"Name": "Rohit", "Runs": 85, "Strike Rate": 142.5}
p2 = {"Name": "Virat", "Runs": 102, "Strike Rate": 135.0}

better = p1["Name"] if p1["Runs"] > p2["Runs"] else p2["Name"]

print(f"{p1['Name']}: {p1['Runs']} runs @ SR {p1['Strike Rate']}")
print(f"{p2['Name']}: {p2['Runs']} runs @ SR {p2['Strike Rate']}")
print("Better Performer:", better)
# Out:
# Rohit: 85 runs @ SR 142.5
# Virat: 102 runs @ SR 135.0
# Better Performer: Virat

# %%
# Q60. University Attendance Monitoring System

attendance = 72

if attendance >= 75:
    status = "Eligible for Examination"
elif attendance >= 65:
    status = "Conditionally Eligible"
else:
    status = "Not Eligible"

print(f"Attendance      : {attendance}%")
print("Status          :", status)
# Out:
# Attendance      : 72%
# Status          : Conditionally Eligible

# %%
# Q61. Travel Budget Planner

budget = 25000
hotel = 8000
transport = 4500
food = 3500
shopping = 5000

total_expense = hotel + transport + food + shopping
remaining = budget - total_expense

print(f"Budget          : Rs. {budget}")
print(f"Hotel           : Rs. {hotel}")
print(f"Transport       : Rs. {transport}")
print(f"Food            : Rs. {food}")
print(f"Shopping        : Rs. {shopping}")
print(f"Total Expense   : Rs. {total_expense}")
print(f"Remaining Budget: Rs. {remaining}")
# Out:
# Budget          : Rs. 25000
# Hotel           : Rs. 8000
# Transport       : Rs. 4500
# Food            : Rs. 3500
# Shopping        : Rs. 5000
# Total Expense   : Rs. 21000
# Remaining Budget: Rs. 4000

# %%
# Q62. Movie Ticket Booking System

ticket_price = 250
num_tickets = 4
convenience_fee = 30
gst_percent = 18

subtotal = ticket_price * num_tickets
gst = (subtotal + convenience_fee) * gst_percent / 100
total = subtotal + convenience_fee + gst

print(f"Ticket Price    : Rs. {ticket_price}")
print(f"No. of Tickets  : {num_tickets}")
print(f"Convenience Fee : Rs. {convenience_fee}")
print(f"GST (18%)       : Rs. {gst:.2f}")
print(f"Total Payable   : Rs. {total:.2f}")
# Out:
# Ticket Price    : Rs. 250
# No. of Tickets  : 4
# Convenience Fee : Rs. 30
# GST (18%)       : Rs. 185.40
# Total Payable   : Rs. 1215.40

# %%
# Q63. Product Inventory Management System

product = {"Name": "USB Drive", "Unit Price": 350, "Stock": 40}
total_value = product["Unit Price"] * product["Stock"]
product["Stock"] -= 5

print(f"Product         : {product['Name']}")
print(f"Total Value     : Rs. {total_value}")
print(f"Updated Stock   : {product['Stock']} units")
# Out:
# Product         : USB Drive
# Total Value     : Rs. 14000
# Updated Stock   : 35 units

# %%
# Q64. University Hostel Allocation System

annual_income = 180000

if annual_income <= 200000:
    hostel = "AC Hostel"
elif annual_income <= 500000:
    hostel = "Non-AC Hostel"
else:
    hostel = "Waiting List"

print(f"Annual Income   : Rs. {annual_income}")
print("Hostel Allocated:", hostel)
# Out:
# Annual Income   : Rs. 180000
# Hostel Allocated: AC Hostel

# %%
# Q65. Weather Monitoring System

celsius = 22
fahrenheit = (celsius * 9/5) + 32

if celsius < 15:
    category = "Cold"
elif celsius <= 30:
    category = "Pleasant"
else:
    category = "Hot"

print(f"Temperature     : {celsius} C")
print(f"In Fahrenheit   : {fahrenheit} F")
print("Weather         :", category)
# Out:
# Temperature     : 22 C
# In Fahrenheit   : 71.6 F
# Weather         : Pleasant

# %%
# Q66. Vehicle Registration Management System

vehicle = {
    "Reg No": "MH12AB1234",
    "Owner": "Suresh Patel",
    "Address": "Pune",
    "Model": "Honda City"
}
vehicle["Address"] = "Mumbai"

print("Updated Vehicle Record:")
for k, v in vehicle.items():
    print(f"  {k}: {v}")
# Out:
# Updated Vehicle Record:
#   Reg No: MH12AB1234
#   Owner: Suresh Patel
#   Address: Mumbai
#   Model: Honda City

# %%
# Q67. Banking Transaction Summary System

opening = 15000
deposit = 5000
withdrawal = 22000
final = opening + deposit - withdrawal

print(f"Opening Balance : Rs. {opening}")
print(f"Deposit         : Rs. {deposit}")
print(f"Withdrawal      : Rs. {withdrawal}")

if final < 0:
    print("Status          : Transaction Declined")
else:
    print(f"Final Balance   : Rs. {final}")
# Out:
# Opening Balance : Rs. 15000
# Deposit         : Rs. 5000
# Withdrawal      : Rs. 22000
# Status          : Transaction Declined

# %%
# Q68. Smartphone Comparison System

s1 = {"Brand": "Samsung", "Model": "Galaxy A54", "Price": 38000, "RAM": "8GB", "Storage": "128GB"}
s2 = {"Brand": "OnePlus", "Model": "Nord CE 3", "Price": 26000, "RAM": "8GB", "Storage": "128GB"}

economical = s1 if s1["Price"] < s2["Price"] else s2

print(f"{s1['Brand']} {s1['Model']}: Rs. {s1['Price']}")
print(f"{s2['Brand']} {s2['Model']}: Rs. {s2['Price']}")
print(f"More Economical : {economical['Brand']} {economical['Model']}")
# Out:
# Samsung Galaxy A54: Rs. 38000
# OnePlus Nord CE 3: Rs. 26000
# More Economical : OnePlus Nord CE 3

# %%
# Q69. Hospital Medicine Inventory System

inventory = {"Paracetamol", "Ibuprofen", "Amoxicillin", "Aspirin"}
inventory.add("Metformin")
inventory.add("Azithromycin")
inventory.discard("Aspirin")

print("Updated Inventory:", sorted(inventory))
# Out:
# Updated Inventory: ['Amoxicillin', 'Azithromycin', 'Ibuprofen', 'Metformin', 'Paracetamol']

# %%
# Q70. College Club Membership Analysis

coding = {"Alice", "Bob", "Charlie", "Diana", "Eve"}
ai_club = {"Bob", "Diana", "Frank", "Grace", "Alice"}

both = coding & ai_club
either = coding | ai_club
only_coding = coding - ai_club

print("Both Clubs       :", sorted(both))
print("Either Club      :", sorted(either))
print("Only Coding Club :", sorted(only_coding))
# Out:
# Both Clubs       : ['Alice', 'Bob', 'Diana']
# Either Club      : ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve', 'Frank', 'Grace']
# Only Coding Club : ['Charlie', 'Eve']

# %%
# Q71. Laptop Recommendation System

budget = 55000

if budget < 35000:
    category = "Basic"
elif budget <= 65000:
    category = "Mid-Range"
else:
    category = "Premium"

print(f"Budget          : Rs. {budget}")
print("Recommended     :", category)
# Out:
# Budget          : Rs. 55000
# Recommended     : Mid-Range

# %%
# Q72. Body Mass Index (BMI) Calculator

height = 1.72
weight = 70
bmi = weight / (height ** 2)

if bmi < 18.5:
    category = "Underweight"
elif bmi < 25:
    category = "Normal"
elif bmi < 30:
    category = "Overweight"
else:
    category = "Obese"

print(f"Height          : {height} m")
print(f"Weight          : {weight} kg")
print(f"BMI             : {bmi:.2f}")
print("Category        :", category)
# Out:
# Height          : 1.72 m
# Weight          : 70 kg
# BMI             : 23.66
# Category        : Normal

# %%
# Q73. Vehicle Insurance Premium Calculator

age = 28
vehicle_value = 800000
accident_history = False

base_rate = 0.03
if age < 25:
    base_rate += 0.005
if accident_history:
    base_rate += 0.01

premium = vehicle_value * base_rate

print(f"Driver Age      : {age}")
print(f"Vehicle Value   : Rs. {vehicle_value}")
print(f"Accident History: {accident_history}")
print(f"Premium Rate    : {base_rate * 100:.1f}%")
print(f"Insurance Premium: Rs. {premium:.2f}")
# Out:
# Driver Age      : 28
# Vehicle Value   : Rs. 800000
# Accident History: False
# Premium Rate    : 3.0%
# Insurance Premium: Rs. 24000.00

# %%
# Q74. Online Streaming Subscription System

plan = "Standard"

if plan == "Basic":
    charge = 149
    features = "SD Quality, 1 Screen"
elif plan == "Standard":
    charge = 299
    features = "HD Quality, 2 Screens"
elif plan == "Premium":
    charge = 549
    features = "4K Quality, 4 Screens, Downloads"
else:
    charge = 0
    features = "Invalid Plan"

print(f"Plan            : {plan}")
print(f"Monthly Charge  : Rs. {charge}")
print(f"Features        : {features}")
# Out:
# Plan            : Standard
# Monthly Charge  : Rs. 299
# Features        : HD Quality, 2 Screens

# %%
# Q75. University Examination Result Processing System

marks = [55, 40, 72, 38, 61]
total = sum(marks)
percentage = total / 500 * 100
passed_all = all(m >= 35 for m in marks)
result = "Pass" if passed_all and percentage >= 40 else "Fail"

print(f"Marks           : {marks}")
print(f"Total           : {total}/500")
print(f"Percentage      : {percentage:.2f}%")
print(f"Result          : {result}")
# Out:
# Marks           : [55, 40, 72, 38, 61]
# Total           : 266/500
# Percentage      : 53.20%
# Result          : Pass

# %%
# Q76. Restaurant Table Allocation System

guests = 8
reservation = "VIP"

if reservation == "VIP":
    table = "VIP Lounge"
elif guests <= 2:
    table = "Small Table"
elif guests <= 5:
    table = "Medium Table"
else:
    table = "Large Table"

print(f"Guests          : {guests}")
print(f"Reservation     : {reservation}")
print(f"Allocated       : {table}")
# Out:
# Guests          : 8
# Reservation     : VIP
# Allocated       : VIP Lounge

# %%
# Q77. Airport Baggage Verification System

baggage_weight = 22

if baggage_weight <= 20:
    status = "No Extra Charge"
elif baggage_weight <= 30:
    status = "Excess Baggage Charge: Rs. 500"
else:
    status = "Not Allowed"

print(f"Baggage Weight  : {baggage_weight} kg")
print("Status          :", status)
# Out:
# Baggage Weight  : 22 kg
# Status          : Excess Baggage Charge: Rs. 500

# %%
# Q78. Hotel Room Billing System

room_type = "Deluxe"
days = 3
base_rate = 4500
discount_pct = 10
gst_pct = 12

subtotal = base_rate * days
discount = subtotal * discount_pct / 100
after_discount = subtotal - discount
gst = after_discount * gst_pct / 100
total = after_discount + gst

print(f"Room Type       : {room_type}")
print(f"Days Stayed     : {days}")
print(f"Subtotal        : Rs. {subtotal}")
print(f"Discount ({discount_pct}%)  : Rs. {discount}")
print(f"GST ({gst_pct}%)      : Rs. {gst:.2f}")
print(f"Total Bill      : Rs. {total:.2f}")
# Out:
# Room Type       : Deluxe
# Days Stayed     : 3
# Subtotal        : Rs. 13500
# Discount (10%)  : Rs. 1350.0
# GST (12%)      : Rs. 1458.00
# Total Bill      : Rs. 13608.00

# %%
# Q79. Smart Water Consumption Monitoring System

consumption = 25000

if consumption <= 10000:
    category = "Low Consumption"
    bill = consumption * 0.005
elif consumption <= 30000:
    category = "Normal Consumption"
    bill = (10000 * 0.005) + (consumption - 10000) * 0.008
else:
    category = "High Consumption"
    bill = (10000 * 0.005) + (20000 * 0.008) + (consumption - 30000) * 0.012

print(f"Consumption     : {consumption} litres")
print(f"Category        : {category}")
print(f"Water Bill      : Rs. {bill:.2f}")
# Out:
# Consumption     : 25000 litres
# Category        : Normal Consumption
# Water Bill      : Rs. 170.00

# %%
# Q80. University Student Information Management System

name = "Arjun Verma"
reg_no = "2024CS101"
department = "Computer Science"
marks = [88, 76, 91, 65, 82]
hostel = True
annual_income = 250000

total = sum(marks)
percentage = total / 500 * 100
highest = max(marks)
lowest = min(marks)

if percentage >= 90:
    grade = "O"
elif percentage >= 80:
    grade = "A+"
elif percentage >= 70:
    grade = "A"
elif percentage >= 60:
    grade = "B"
else:
    grade = "C"

print("=" * 45)
print("           STUDENT REPORT")
print("=" * 45)
print(f"Name            : {name}")
print(f"Reg. No.        : {reg_no}")
print(f"Department      : {department}")
print(f"Marks           : {marks}")
print(f"Total           : {total}/500")
print(f"Percentage      : {percentage:.2f}%")
print(f"Highest Mark    : {highest}")
print(f"Lowest Mark     : {lowest}")
print(f"Grade           : {grade}")
print("-" * 45)
if annual_income < 300000 and percentage >= 80:
    print("Eligible for Merit-cum-Means Scholarship")
if hostel:
    print("Hostel Allocation Request Generated")
print("=" * 45)
# Out:
# ...
#            STUDENT REPORT
# ...
# Name            : Arjun Verma
# Reg. No.        : 2024CS101
# Department      : Computer Science
# Marks           : [88, 76, 91, 65, 82]
# Total           : 402/500
# Percentage      : 80.40%
# Highest Mark    : 91
# Lowest Mark     : 65
# Grade           : A+
# ---------------------------------------------
# Eligible for Merit-cum-Means Scholarship
# Hostel Allocation Request Generated
# ...
